# %% [markdown]
# #Etapa 1: Importando bibliotecas

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os
from numpy.random import choice as npc
import numpy as np
import time
import random
import shutil
import torchvision.datasets as dset
from PIL import Image
import pickle
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn as sns
import time
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# #Etapa 2: Carregando o Dataset

# %% [markdown]
# Nesta etapa iremos carregar o dataset Omniglot. Carregaremos o [dataset](https://github.com/brendenlake/omniglot/tree/master/python) images_background e images_evaluation e iremos carregar no ambiente do Colab em duas pastas diferentes

# %%
from google.colab import drive
drive.mount('/content/drive')



# Caminhos originais
train_path_background = '/content/drive/MyDrive/Faculdade/2025.1/images_background/images_background'
test_path_evaluation = "/content/drive/MyDrive/Faculdade/2025.1/images_evaluation/images_evaluation"

# Novos caminhos reestruturados
train_reestruturado = '/content/images_background_reestruturado'
test_reestruturado = '/content/images_evaluation_reestruturado'

def reestruturar_omniglot(origem, destino):
    if not os.path.exists(destino):
        os.makedirs(destino)

    for idioma in os.listdir(origem):
        caminho_idioma = os.path.join(origem, idioma)
        if os.path.isdir(caminho_idioma):
            for caractere in os.listdir(caminho_idioma):
                caminho_caractere = os.path.join(caminho_idioma, caractere)
                if os.path.isdir(caminho_caractere):
                    novo_nome = f"{idioma}_{caractere}"
                    destino_caractere = os.path.join(destino, novo_nome)
                    if not os.path.exists(destino_caractere):
                        shutil.copytree(caminho_caractere, destino_caractere)

# Executa reestruturação
reestruturar_omniglot(train_path_background, train_reestruturado)
reestruturar_omniglot(test_path_evaluation, test_reestruturado)

# Usa os novos caminhos no ImageFolder
train_dataset = dset.ImageFolder(root=train_reestruturado)
test_dataset = dset.ImageFolder(root=test_reestruturado)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Etapa 3: Pré-processando o dataset de treinamento

# %%
class OmniglotTrain(Dataset):

    def __init__(self, dataset, transform=None):
        super(OmniglotTrain, self).__init__()
        np.random.seed(0)
        self.dataset = dataset
        self.transform = transform
        self.img1 = None

    def __len__(self):
        return  21000000

    def __getitem__(self, index):
        image1 = random.choice(self.dataset.imgs)
        # get image from same class
        label = None
        if index % 2 == 1:
            label = 1.0
            while True:
                image2 = random.choice(self.dataset.imgs)
                if image1[1] == image2[1]:
                    break
        # get image from different class
        else:
            label = 0.0
            while True:
                image2 = random.choice(self.dataset.imgs)
                if image1[1] != image2[1]:
                    break
        image1 = Image.open(image1[0])
        image2 = Image.open(image2[0])
        image1 = image1.convert('L')
        image2 = image2.convert('L')

        if self.transform:
            image1 = self.transform(image1)
            image2 = self.transform(image2)
        return image1, image2, torch.from_numpy(np.array([label], dtype=np.float32))

# %% [markdown]
# #Etapa 4: Pré-processando o dataset de teste

# %%
class OmniglotTest(Dataset):

    def __init__(self, dataset, transform=None, times=200, way=20):
        np.random.seed(1)
        super(OmniglotTest, self).__init__()
        self.dataset = dataset
        self.transform = transform
        self.times = times
        self.way = way

    def __len__(self):
        return self.times * self.way

    def __getitem__(self, index):
        idx = index % self.way
        label = None
        # generate image pair from same class
        if idx == 0:
            self.img1 = random.choice(self.dataset.imgs)
            while True:
                img2 = random.choice(self.dataset.imgs)
                if self.img1[1] == img2[1]:
                    break
        # generate image pair from different class
        else:
            while True:
                img2 = random.choice(self.dataset.imgs)
                if self.img1[1] != img2[1]:
                    break

        img1 = Image.open(self.img1[0])
        img2 = Image.open(img2[0])
        img1 = img1.convert('L')
        img2 = img2.convert('L')

        if self.transform:
            img1 = self.transform(img1)
            img2 = self.transform(img2)
        return img1, img2

# %% [markdown]
# ##Etapa 5: Modelo

# %%
class Siamese(nn.Module):

    def __init__(self):
        super(Siamese, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, 10),  # 64@96*96
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),  # 64@48*48
            nn.Conv2d(64, 128, 7),
            nn.ReLU(),    # 128@42*42
            nn.MaxPool2d(2),   # 128@21*21
            nn.Conv2d(128, 128, 4),
            nn.ReLU(), # 128@18*18
            nn.MaxPool2d(2), # 128@9*9
            nn.Conv2d(128, 256, 4),
            nn.ReLU(),   # 256@6*6
        )
        self.liner = nn.Sequential(nn.Linear(9216, 4096), nn.Sigmoid())
        self.out = nn.Linear(4096, 1)

    def forward_one(self, x):
        x = self.conv(x)
        x = x.view(x.size()[0], -1)
        x = self.liner(x)
        return x

    def forward(self, x1, x2):
        out1 = self.forward_one(x1)
        out2 = self.forward_one(x2)
        dis = torch.abs(out1 - out2)
        out = self.out(dis)
        #  return self.sigmoid(out)
        return out

# %% [markdown]
# #Etapa 6: Checagem da GPU

# %%
cuda = torch.cuda.is_available()
print("Cuda: " + str(cuda))          #Checking if CUDA is available
# Out:
# Cuda: True

# %% [markdown]
# #Etapa 7: Afinar distorções

# %%
data_transforms = transforms.Compose([
    transforms.RandomAffine(15),
    transforms.ToTensor()
])

# %% [markdown]
# #Etapa 8: Carregando os dados e criando pares para treinamento e teste

# %%
way = 20
times = 400

dataSet = OmniglotTrain(train_dataset, transform=data_transforms)
testSet = OmniglotTest(test_dataset, transform=transforms.ToTensor(), times = times, way = way)
testLoader = DataLoader(testSet, batch_size=way, shuffle=False, num_workers=16)

dataLoader = DataLoader(dataSet, batch_size=128,\
                        shuffle=False, num_workers=16)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %% [markdown]
# #Etapa 9: Função de Perda

# %%
loss_fn = torch.nn.BCEWithLogitsLoss(size_average=True)
learning_rate = 0.0006
net = Siamese()
train_loss = []
net.train()
if cuda:
    net.cuda()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %% [markdown]
# #Etapa 10: Otimizador

# %%
optimizer = torch.optim.Adam(net.parameters(),lr = learning_rate )
optimizer.zero_grad()

# %% [markdown]
# #Etapa 11: Setando os parâmetros

# %%
show_every = 10
save_every = 100
test_every = 100
train_loss = []
loss_val = 0
max_iter = 90000
losses=[]
batch_ids= []

# %% [markdown]
# #Etapa X: Avaliacao One Shot

# %%
def evaluate_oneshot(net, dataset, way=20, times=400, cuda=True):
    print("Realizando avaliação One-Shot...")
    net.eval()
    correct = 0

    with torch.no_grad():
        for _ in range(times):
            # Escolhe aleatoriamente uma classe
            classes = list(set([img[1] for img in dataset.dataset.imgs]))
            selected_classes = random.sample(classes, way)
            correct_class = selected_classes[0]

            # Escolhe imagem de suporte da classe correta
            support_imgs = [img for img in dataset.dataset.imgs if img[1] == correct_class]
            support_path = random.choice(support_imgs)[0]
            support_img = Image.open(support_path).convert('L')
            support_img = dataset.transform(support_img).unsqueeze(0)
            if cuda:
                support_img = support_img.cuda()

            # Escolhe um candidato por classe (inclusive da correta)
            candidates = []
            for cls in selected_classes:
                imgs = [img for img in dataset.dataset.imgs if img[1] == cls]
                path = random.choice(imgs)[0]
                img = Image.open(path).convert('L')
                img = dataset.transform(img).unsqueeze(0)
                if cuda:
                    img = img.cuda()
                candidates.append(img)

            # Extrai embedding do suporte
            emb_support = net.forward_one(support_img)

            distances = []
            for candidate in candidates:
                emb_candidate = net.forward_one(candidate)
                dist = F.pairwise_distance(emb_support, emb_candidate)
                distances.append(dist.item())

            pred = np.argmin(distances)
            if pred == 0:
                correct += 1

    acc = correct / times * 100
    print(f"\nOne-Shot Accuracy on {way}-way {times}-trial: {correct}/{times} = {acc:.2f}%")
    return correct, times

# %% [markdown]
# #Etapa 12: Treinando e testando a cada 100 batch size

# %%
if not os.path.exists('model'):
    os.makedirs('model')

for batch_id, (img1, img2, label) in enumerate(dataLoader, 1):
    if batch_id > max_iter:
        break
    batch_start = time.time()
    if cuda:
        img1, img2, label = Variable(img1.cuda()), Variable(img2.cuda()), Variable(label.cuda())
    else:
        img1, img2, label = Variable(img1), Variable(img2), Variable(label)
    optimizer.zero_grad()
    output = net.forward(img1, img2)
    loss = loss_fn(output, label)
    loss_val += loss.item()
    loss.backward()
    optimizer.step()
    if batch_id % show_every == 0 :
        print('[%d]\tloss:\t%.5f\tTook\t%.2f s'%(batch_id, loss_val/show_every, (time.time() - batch_start)*show_every))
        batch_ids.append(float(batch_id))
        losses.append(loss_val/show_every)
        loss_val = 0
    if batch_id % save_every == 0:
        torch.save(net.state_dict(), 'model/model-batch-%d.pth'%(batch_id+1,))
    if batch_id % test_every == 0:
        evaluate_oneshot(net, testSet, way=way, times=times, cuda=cuda)
    train_loss.append(loss_val)
#  learning_rate = learning_rate * 0.95

with open('train_loss', 'wb') as f:
    pickle.dump(train_loss, f)
# Out:
# [10]	loss:	0.32940	Took	2.44 s
# [20]	loss:	0.30769	Took	2.61 s
# [30]	loss:	0.29528	Took	2.70 s
# [40]	loss:	0.27448	Took	2.70 s
# [50]	loss:	0.25522	Took	2.62 s
# [60]	loss:	0.26124	Took	2.63 s
# [70]	loss:	0.27556	Took	2.63 s
# [80]	loss:	0.29228	Took	2.55 s
# [90]	loss:	0.27282	Took	2.76 s
# [100]	loss:	0.24809	Took	2.59 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 241/400 = 60.25%
# [110]	loss:	0.26999	Took	2.66 s
# [120]	loss:	0.29848	Took	2.55 s
# [130]	loss:	0.26671	Took	2.66 s
# [140]	loss:	0.28302	Took	2.67 s
# [150]	loss:	0.23238	Took	2.65 s
# [160]	loss:	0.24908	Took	2.66 s
# [170]	loss:	0.26609	Took	2.69 s
# [180]	loss:	0.22290	Took	2.72 s
# [190]	loss:	0.21882	Took	2.74 s
# [200]	loss:	0.23268	Took	2.68 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 249/400 = 62.25%
# [210]	loss:	0.22066	Took	2.77 s
# [220]	loss:	0.22199	Took	2.67 s
# [230]	loss:	0.24624	Took	2.72 s
# [240]	loss:	0.23821	Took	2.78 s
# [250]	loss:	0.25610	Took	2.69 s
# [260]	loss:	0.21627	Took	2.70 s
# [270]	loss:	0.23050	Took	2.67 s
# [280]	loss:	0.22102	Took	2.75 s
# [290]	loss:	0.26265	Took	2.68 s
# [300]	loss:	0.21953	Took	2.71 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 252/400 = 63.00%
# [310]	loss:	0.21333	Took	2.62 s
# [320]	loss:	0.21159	Took	2.75 s
# [330]	loss:	0.21493	Took	2.78 s
# [340]	loss:	0.18627	Took	2.75 s
# [350]	loss:	0.18410	Took	2.87 s
# [360]	loss:	0.20873	Took	2.84 s
# [370]	loss:	0.22899	Took	2.78 s
# [380]	loss:	0.20520	Took	2.75 s
# [390]	loss:	0.21089	Took	2.78 s
# [400]	loss:	0.22045	Took	2.80 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 256/400 = 64.00%
# [410]	loss:	0.20560	Took	2.80 s
# [420]	loss:	0.25087	Took	2.79 s
# [430]	loss:	0.21265	Took	2.77 s
# [440]	loss:	0.20903	Took	2.79 s
# [450]	loss:	0.18105	Took	2.75 s
# [460]	loss:	0.20816	Took	2.57 s
# [470]	loss:	0.21992	Took	2.76 s
# [480]	loss:	0.20675	Took	2.76 s
# [490]	loss:	0.21766	Took	2.76 s
# [500]	loss:	0.19527	Took	2.83 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 246/400 = 61.50%
# [510]	loss:	0.18734	Took	2.72 s
# [520]	loss:	0.19887	Took	2.58 s
# [530]	loss:	0.22852	Took	2.64 s
# [540]	loss:	0.18067	Took	2.76 s
# [550]	loss:	0.19763	Took	2.75 s
# [560]	loss:	0.22078	Took	2.75 s
# [570]	loss:	0.18223	Took	2.80 s
# [580]	loss:	0.18536	Took	2.98 s
# [590]	loss:	0.18145	Took	2.74 s
# [600]	loss:	0.19493	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 263/400 = 65.75%
# [610]	loss:	0.19880	Took	2.88 s
# [620]	loss:	0.19034	Took	2.67 s
# [630]	loss:	0.18051	Took	2.79 s
# [640]	loss:	0.18218	Took	2.76 s
# [650]	loss:	0.16763	Took	2.77 s
# [660]	loss:	0.17889	Took	2.55 s
# [670]	loss:	0.17987	Took	2.66 s
# [680]	loss:	0.19078	Took	2.79 s
# [690]	loss:	0.18966	Took	2.74 s
# [700]	loss:	0.21110	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 274/400 = 68.50%
# [710]	loss:	0.16815	Took	2.76 s
# [720]	loss:	0.13138	Took	2.75 s
# [730]	loss:	0.17926	Took	2.62 s
# [740]	loss:	0.16354	Took	2.66 s
# [750]	loss:	0.15805	Took	2.86 s
# [760]	loss:	0.18522	Took	2.75 s
# [770]	loss:	0.16608	Took	2.76 s
# [780]	loss:	0.15155	Took	2.76 s
# [790]	loss:	0.15993	Took	2.75 s
# [800]	loss:	0.16350	Took	2.89 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 262/400 = 65.50%
# [810]	loss:	0.16500	Took	2.75 s
# [820]	loss:	0.20258	Took	2.84 s
# [830]	loss:	0.15593	Took	2.78 s
# [840]	loss:	0.17295	Took	2.83 s
# [850]	loss:	0.16404	Took	2.83 s
# [860]	loss:	0.15659	Took	2.73 s
# [870]	loss:	0.17851	Took	2.76 s
# [880]	loss:	0.16041	Took	2.75 s
# [890]	loss:	0.16164	Took	2.80 s
# [900]	loss:	0.18198	Took	2.81 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 253/400 = 63.25%
# [910]	loss:	0.17090	Took	2.73 s
# [920]	loss:	0.14560	Took	2.79 s
# [930]	loss:	0.13621	Took	2.81 s
# [940]	loss:	0.15746	Took	2.73 s
# [950]	loss:	0.14918	Took	2.74 s
# [960]	loss:	0.16297	Took	2.71 s
# [970]	loss:	0.14554	Took	2.73 s
# [980]	loss:	0.15842	Took	2.78 s
# [990]	loss:	0.19212	Took	2.70 s
# [1000]	loss:	0.14562	Took	2.73 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 261/400 = 65.25%
# [1010]	loss:	0.14088	Took	2.68 s
# [1020]	loss:	0.14497	Took	2.82 s
# [1030]	loss:	0.14762	Took	2.75 s
# [1040]	loss:	0.15921	Took	2.77 s
# [1050]	loss:	0.15742	Took	2.75 s
# [1060]	loss:	0.16033	Took	2.87 s
# [1070]	loss:	0.13989	Took	2.86 s
# [1080]	loss:	0.16900	Took	2.74 s
# [1090]	loss:	0.14999	Took	2.73 s
# [1100]	loss:	0.11865	Took	2.71 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 278/400 = 69.50%
# [1110]	loss:	0.13119	Took	2.75 s
# [1120]	loss:	0.17664	Took	2.71 s
# [1130]	loss:	0.12734	Took	2.75 s
# [1140]	loss:	0.16206	Took	2.72 s
# [1150]	loss:	0.17782	Took	2.80 s
# [1160]	loss:	0.15637	Took	2.80 s
# [1170]	loss:	0.15163	Took	2.73 s
# [1180]	loss:	0.16557	Took	2.76 s
# [1190]	loss:	0.12843	Took	2.74 s
# [1200]	loss:	0.13751	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 278/400 = 69.50%
# [1210]	loss:	0.14584	Took	2.75 s
# [1220]	loss:	0.12263	Took	2.68 s
# [1230]	loss:	0.13601	Took	2.81 s
# [1240]	loss:	0.15624	Took	2.66 s
# [1250]	loss:	0.14908	Took	2.74 s
# [1260]	loss:	0.13348	Took	2.74 s
# [1270]	loss:	0.13518	Took	2.75 s
# [1280]	loss:	0.15539	Took	2.80 s
# [1290]	loss:	0.11631	Took	2.60 s
# [1300]	loss:	0.14588	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 272/400 = 68.00%
# [1310]	loss:	0.12715	Took	2.70 s
# [1320]	loss:	0.13591	Took	2.82 s
# [1330]	loss:	0.14469	Took	2.74 s
# [1340]	loss:	0.13015	Took	2.75 s
# [1350]	loss:	0.13228	Took	2.72 s
# [1360]	loss:	0.14875	Took	2.75 s
# [1370]	loss:	0.13544	Took	2.88 s
# [1380]	loss:	0.13844	Took	2.76 s
# [1390]	loss:	0.13532	Took	2.77 s
# [1400]	loss:	0.12296	Took	2.73 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 285/400 = 71.25%
# [1410]	loss:	0.11580	Took	2.78 s
# [1420]	loss:	0.13422	Took	2.73 s
# [1430]	loss:	0.12416	Took	2.66 s
# [1440]	loss:	0.14820	Took	2.74 s
# [1450]	loss:	0.11209	Took	2.57 s
# [1460]	loss:	0.12006	Took	2.69 s
# [1470]	loss:	0.11495	Took	2.74 s
# [1480]	loss:	0.11136	Took	2.74 s
# [1490]	loss:	0.11930	Took	2.71 s
# [1500]	loss:	0.12347	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 276/400 = 69.00%
# [1510]	loss:	0.15023	Took	2.74 s
# [1520]	loss:	0.12388	Took	2.76 s
# [1530]	loss:	0.11767	Took	2.66 s
# [1540]	loss:	0.11613	Took	2.76 s
# [1550]	loss:	0.12649	Took	2.72 s
# [1560]	loss:	0.10432	Took	2.74 s
# [1570]	loss:	0.14508	Took	2.75 s
# [1580]	loss:	0.10818	Took	2.86 s
# [1590]	loss:	0.12082	Took	2.67 s
# [1600]	loss:	0.14564	Took	2.73 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 290/400 = 72.50%
# [1610]	loss:	0.12957	Took	2.72 s
# [1620]	loss:	0.12527	Took	2.77 s
# [1630]	loss:	0.10345	Took	2.63 s
# [1640]	loss:	0.10795	Took	2.75 s
# [1650]	loss:	0.13616	Took	2.76 s
# [1660]	loss:	0.13955	Took	2.80 s
# [1670]	loss:	0.11582	Took	2.69 s
# [1680]	loss:	0.13054	Took	2.77 s
# [1690]	loss:	0.10406	Took	2.74 s
# [1700]	loss:	0.11497	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 277/400 = 69.25%
# [1710]	loss:	0.11375	Took	2.73 s
# [1720]	loss:	0.12329	Took	2.78 s
# [1730]	loss:	0.12763	Took	2.71 s
# [1740]	loss:	0.11705	Took	2.75 s
# [1750]	loss:	0.09794	Took	2.76 s
# [1760]	loss:	0.11189	Took	2.77 s
# [1770]	loss:	0.10232	Took	2.76 s
# [1780]	loss:	0.12111	Took	2.70 s
# [1790]	loss:	0.14423	Took	2.74 s
# [1800]	loss:	0.11453	Took	2.79 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 305/400 = 76.25%
# [1810]	loss:	0.12824	Took	2.76 s
# [1820]	loss:	0.13700	Took	2.72 s
# [1830]	loss:	0.11370	Took	2.82 s
# [1840]	loss:	0.14936	Took	2.77 s
# [1850]	loss:	0.11287	Took	2.74 s
# [1860]	loss:	0.14145	Took	2.76 s
# [1870]	loss:	0.11747	Took	2.74 s
# [1880]	loss:	0.12088	Took	2.73 s
# [1890]	loss:	0.11173	Took	2.78 s
# [1900]	loss:	0.11277	Took	2.79 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 287/400 = 71.75%
# [1910]	loss:	0.13722	Took	2.74 s
# [1920]	loss:	0.11823	Took	2.80 s
# [1930]	loss:	0.11545	Took	2.69 s
# [1940]	loss:	0.11993	Took	2.74 s
# [1950]	loss:	0.13159	Took	2.73 s
# [1960]	loss:	0.12137	Took	2.77 s
# [1970]	loss:	0.12902	Took	2.56 s
# [1980]	loss:	0.10445	Took	2.68 s
# [1990]	loss:	0.13005	Took	2.77 s
# [2000]	loss:	0.10208	Took	2.73 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 277/400 = 69.25%
# [2010]	loss:	0.10795	Took	2.76 s
# [2020]	loss:	0.08060	Took	2.74 s
# [2030]	loss:	0.12095	Took	2.76 s
# [2040]	loss:	0.12617	Took	2.75 s
# [2050]	loss:	0.11587	Took	2.67 s
# [2060]	loss:	0.11133	Took	2.64 s
# [2070]	loss:	0.10174	Took	2.66 s
# [2080]	loss:	0.10178	Took	2.74 s
# [2090]	loss:	0.10882	Took	2.76 s
# [2100]	loss:	0.12617	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 292/400 = 73.00%
# [2110]	loss:	0.10300	Took	2.72 s
# [2120]	loss:	0.11090	Took	2.76 s
# [2130]	loss:	0.12148	Took	2.76 s
# [2140]	loss:	0.10458	Took	2.70 s
# [2150]	loss:	0.10103	Took	2.73 s
# [2160]	loss:	0.11620	Took	2.72 s
# [2170]	loss:	0.10473	Took	2.74 s
# [2180]	loss:	0.10408	Took	2.77 s
# [2190]	loss:	0.08470	Took	2.72 s
# [2200]	loss:	0.12532	Took	2.47 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 304/400 = 76.00%
# [2210]	loss:	0.10907	Took	2.79 s
# [2220]	loss:	0.11436	Took	2.79 s
# [2230]	loss:	0.10103	Took	2.84 s
# [2240]	loss:	0.08914	Took	2.81 s
# [2250]	loss:	0.11623	Took	2.77 s
# [2260]	loss:	0.09303	Took	2.80 s
# [2270]	loss:	0.09915	Took	2.78 s
# [2280]	loss:	0.11864	Took	2.84 s
# [2290]	loss:	0.08476	Took	2.80 s
# [2300]	loss:	0.11831	Took	2.79 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 290/400 = 72.50%
# [2310]	loss:	0.10061	Took	2.79 s
# [2320]	loss:	0.11148	Took	2.78 s
# [2330]	loss:	0.12449	Took	2.77 s
# [2340]	loss:	0.10842	Took	2.76 s
# [2350]	loss:	0.08848	Took	2.84 s
# [2360]	loss:	0.11572	Took	2.79 s
# [2370]	loss:	0.07957	Took	2.74 s
# [2380]	loss:	0.10754	Took	2.74 s
# [2390]	loss:	0.11509	Took	2.75 s
# [2400]	loss:	0.11072	Took	2.67 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 300/400 = 75.00%
# [2410]	loss:	0.10675	Took	2.76 s
# [2420]	loss:	0.08302	Took	2.77 s
# [2430]	loss:	0.09267	Took	2.71 s
# [2440]	loss:	0.08315	Took	2.77 s
# [2450]	loss:	0.09503	Took	2.73 s
# [2460]	loss:	0.12019	Took	2.72 s
# [2470]	loss:	0.09362	Took	2.76 s
# [2480]	loss:	0.10576	Took	2.74 s
# [2490]	loss:	0.11062	Took	2.86 s
# [2500]	loss:	0.07697	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 299/400 = 74.75%
# [2510]	loss:	0.09924	Took	2.75 s
# [2520]	loss:	0.09999	Took	2.75 s
# [2530]	loss:	0.08675	Took	2.77 s
# [2540]	loss:	0.07234	Took	2.75 s
# [2550]	loss:	0.09341	Took	2.75 s
# [2560]	loss:	0.09275	Took	2.74 s
# [2570]	loss:	0.08711	Took	2.74 s
# [2580]	loss:	0.10108	Took	2.74 s
# [2590]	loss:	0.07841	Took	2.78 s
# [2600]	loss:	0.06682	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 308/400 = 77.00%
# [2610]	loss:	0.09729	Took	2.77 s
# [2620]	loss:	0.07912	Took	2.71 s
# [2630]	loss:	0.09604	Took	2.77 s
# [2640]	loss:	0.10553	Took	2.77 s
# [2650]	loss:	0.10916	Took	2.82 s
# [2660]	loss:	0.08889	Took	2.76 s
# [2670]	loss:	0.09593	Took	2.73 s
# [2680]	loss:	0.07450	Took	2.77 s
# [2690]	loss:	0.10696	Took	2.64 s
# [2700]	loss:	0.09183	Took	2.79 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 292/400 = 73.00%
# [2710]	loss:	0.08467	Took	2.71 s
# [2720]	loss:	0.08853	Took	2.74 s
# [2730]	loss:	0.07183	Took	2.73 s
# [2740]	loss:	0.09212	Took	2.80 s
# [2750]	loss:	0.10194	Took	2.74 s
# [2760]	loss:	0.09688	Took	2.72 s
# [2770]	loss:	0.12415	Took	2.74 s
# [2780]	loss:	0.08975	Took	2.75 s
# [2790]	loss:	0.08402	Took	2.73 s
# [2800]	loss:	0.10086	Took	2.78 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 295/400 = 73.75%
# [2810]	loss:	0.07889	Took	2.76 s
# [2820]	loss:	0.10052	Took	2.79 s
# [2830]	loss:	0.07941	Took	2.68 s
# [2840]	loss:	0.09750	Took	2.73 s
# [2850]	loss:	0.08745	Took	2.76 s
# [2860]	loss:	0.09399	Took	2.76 s
# [2870]	loss:	0.09292	Took	2.79 s
# [2880]	loss:	0.09912	Took	2.75 s
# [2890]	loss:	0.08670	Took	2.73 s
# [2900]	loss:	0.09972	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 300/400 = 75.00%
# [2910]	loss:	0.08491	Took	2.70 s
# [2920]	loss:	0.09435	Took	2.73 s
# [2930]	loss:	0.11282	Took	2.76 s
# [2940]	loss:	0.08245	Took	2.70 s
# [2950]	loss:	0.07826	Took	2.79 s
# [2960]	loss:	0.09808	Took	2.69 s
# [2970]	loss:	0.08472	Took	2.75 s
# [2980]	loss:	0.07559	Took	2.76 s
# [2990]	loss:	0.07721	Took	2.74 s
# [3000]	loss:	0.08936	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 295/400 = 73.75%
# [3010]	loss:	0.07459	Took	2.76 s
# [3020]	loss:	0.10048	Took	2.70 s
# [3030]	loss:	0.08459	Took	2.64 s
# [3040]	loss:	0.07902	Took	2.77 s
# [3050]	loss:	0.08543	Took	2.75 s
# [3060]	loss:	0.08458	Took	2.75 s
# [3070]	loss:	0.09474	Took	2.69 s
# [3080]	loss:	0.09076	Took	2.76 s
# [3090]	loss:	0.09004	Took	2.82 s
# [3100]	loss:	0.07112	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 299/400 = 74.75%
# [3110]	loss:	0.07604	Took	2.75 s
# [3120]	loss:	0.10391	Took	2.79 s
# [3130]	loss:	0.07786	Took	2.70 s
# [3140]	loss:	0.09776	Took	2.74 s
# [3150]	loss:	0.08510	Took	2.75 s
# [3160]	loss:	0.07930	Took	2.74 s
# [3170]	loss:	0.08891	Took	2.65 s
# [3180]	loss:	0.09245	Took	2.76 s
# [3190]	loss:	0.09209	Took	2.73 s
# [3200]	loss:	0.09178	Took	2.73 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 282/400 = 70.50%
# [3210]	loss:	0.08447	Took	2.83 s
# [3220]	loss:	0.08974	Took	2.77 s
# [3230]	loss:	0.08853	Took	2.72 s
# [3240]	loss:	0.09096	Took	2.73 s
# [3250]	loss:	0.09481	Took	2.79 s
# [3260]	loss:	0.09791	Took	2.83 s
# [3270]	loss:	0.10194	Took	2.77 s
# [3280]	loss:	0.08322	Took	2.74 s
# [3290]	loss:	0.07860	Took	2.70 s
# [3300]	loss:	0.08333	Took	2.84 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 293/400 = 73.25%
# [3310]	loss:	0.09065	Took	2.71 s
# [3320]	loss:	0.07920	Took	2.72 s
# [3330]	loss:	0.10537	Took	2.78 s
# [3340]	loss:	0.09191	Took	2.62 s
# [3350]	loss:	0.09558	Took	2.73 s
# [3360]	loss:	0.09386	Took	2.75 s
# [3370]	loss:	0.07681	Took	2.72 s
# [3380]	loss:	0.07007	Took	2.77 s
# [3390]	loss:	0.09017	Took	2.75 s
# [3400]	loss:	0.07739	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 300/400 = 75.00%
# [3410]	loss:	0.07304	Took	2.77 s
# [3420]	loss:	0.09136	Took	2.75 s
# [3430]	loss:	0.08754	Took	2.76 s
# [3440]	loss:	0.07800	Took	2.72 s
# [3450]	loss:	0.08934	Took	2.75 s
# [3460]	loss:	0.08336	Took	2.73 s
# [3470]	loss:	0.10564	Took	2.77 s
# [3480]	loss:	0.08339	Took	2.74 s
# [3490]	loss:	0.05902	Took	2.73 s
# [3500]	loss:	0.08339	Took	2.73 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 311/400 = 77.75%
# [3510]	loss:	0.06608	Took	2.72 s
# [3520]	loss:	0.09529	Took	2.73 s
# [3530]	loss:	0.07831	Took	2.75 s
# [3540]	loss:	0.09102	Took	2.72 s
# [3550]	loss:	0.07669	Took	2.84 s
# [3560]	loss:	0.07827	Took	2.78 s
# [3570]	loss:	0.09994	Took	2.58 s
# [3580]	loss:	0.06367	Took	2.73 s
# [3590]	loss:	0.07141	Took	2.75 s
# [3600]	loss:	0.06646	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 307/400 = 76.75%
# [3610]	loss:	0.07730	Took	2.76 s
# [3620]	loss:	0.08338	Took	2.74 s
# [3630]	loss:	0.07919	Took	2.68 s
# [3640]	loss:	0.06967	Took	2.71 s
# [3650]	loss:	0.09088	Took	2.74 s
# [3660]	loss:	0.11272	Took	2.69 s
# [3670]	loss:	0.10026	Took	2.71 s
# [3680]	loss:	0.10300	Took	2.73 s
# [3690]	loss:	0.07250	Took	2.82 s
# [3700]	loss:	0.10516	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 290/400 = 72.50%
# [3710]	loss:	0.06367	Took	2.72 s
# [3720]	loss:	0.09251	Took	2.74 s
# [3730]	loss:	0.08574	Took	2.63 s
# [3740]	loss:	0.07045	Took	2.78 s
# [3750]	loss:	0.07636	Took	2.75 s
# [3760]	loss:	0.09522	Took	2.72 s
# [3770]	loss:	0.08434	Took	2.68 s
# [3780]	loss:	0.06855	Took	2.64 s
# [3790]	loss:	0.07592	Took	2.74 s
# [3800]	loss:	0.08095	Took	2.70 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 302/400 = 75.50%
# [3810]	loss:	0.07668	Took	2.50 s
# [3820]	loss:	0.07961	Took	2.71 s
# [3830]	loss:	0.07286	Took	2.73 s
# [3840]	loss:	0.08348	Took	2.76 s
# [3850]	loss:	0.07543	Took	2.57 s
# [3860]	loss:	0.08684	Took	2.80 s
# [3870]	loss:	0.07038	Took	2.72 s
# [3880]	loss:	0.07925	Took	2.75 s
# [3890]	loss:	0.07193	Took	2.76 s
# [3900]	loss:	0.07382	Took	2.72 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 292/400 = 73.00%
# [3910]	loss:	0.08173	Took	2.73 s
# [3920]	loss:	0.07260	Took	2.66 s
# [3930]	loss:	0.08227	Took	2.65 s
# [3940]	loss:	0.07253	Took	2.72 s
# [3950]	loss:	0.06783	Took	2.75 s
# [3960]	loss:	0.07563	Took	2.71 s
# [3970]	loss:	0.08839	Took	2.74 s
# [3980]	loss:	0.07444	Took	2.74 s
# [3990]	loss:	0.06752	Took	2.71 s
# [4000]	loss:	0.08566	Took	2.64 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 287/400 = 71.75%
# [4010]	loss:	0.08100	Took	2.75 s
# [4020]	loss:	0.06608	Took	2.75 s
# [4030]	loss:	0.06509	Took	2.68 s
# [4040]	loss:	0.08450	Took	2.74 s
# [4050]	loss:	0.06637	Took	2.73 s
# [4060]	loss:	0.06960	Took	2.75 s
# [4070]	loss:	0.06365	Took	2.79 s
# [4080]	loss:	0.07893	Took	2.76 s
# [4090]	loss:	0.05654	Took	2.74 s
# [4100]	loss:	0.07508	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 283/400 = 70.75%
# [4110]	loss:	0.07617	Took	2.79 s
# [4120]	loss:	0.07124	Took	2.81 s
# [4130]	loss:	0.06685	Took	2.82 s
# [4140]	loss:	0.09552	Took	2.84 s
# [4150]	loss:	0.09166	Took	2.79 s
# [4160]	loss:	0.10000	Took	2.90 s
# [4170]	loss:	0.10758	Took	2.81 s
# [4180]	loss:	0.07525	Took	2.80 s
# [4190]	loss:	0.07296	Took	2.79 s
# [4200]	loss:	0.08022	Took	2.80 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 298/400 = 74.50%
# [4210]	loss:	0.07307	Took	2.70 s
# [4220]	loss:	0.05980	Took	2.77 s
# [4230]	loss:	0.07525	Took	2.78 s
# [4240]	loss:	0.08512	Took	2.81 s
# [4250]	loss:	0.07268	Took	2.75 s
# [4260]	loss:	0.07805	Took	2.72 s
# [4270]	loss:	0.07149	Took	2.71 s
# [4280]	loss:	0.07679	Took	2.75 s
# [4290]	loss:	0.07559	Took	2.86 s
# [4300]	loss:	0.07947	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 309/400 = 77.25%
# [4310]	loss:	0.08184	Took	2.74 s
# [4320]	loss:	0.08050	Took	2.75 s
# [4330]	loss:	0.06025	Took	2.65 s
# [4340]	loss:	0.06063	Took	2.78 s
# [4350]	loss:	0.06548	Took	2.75 s
# [4360]	loss:	0.08928	Took	2.78 s
# [4370]	loss:	0.05147	Took	2.70 s
# [4380]	loss:	0.07501	Took	2.77 s
# [4390]	loss:	0.07664	Took	2.77 s
# [4400]	loss:	0.08226	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 289/400 = 72.25%
# [4410]	loss:	0.08074	Took	2.62 s
# [4420]	loss:	0.07796	Took	2.74 s
# [4430]	loss:	0.07676	Took	2.76 s
# [4440]	loss:	0.07248	Took	2.75 s
# [4450]	loss:	0.06571	Took	2.78 s
# [4460]	loss:	0.06704	Took	2.72 s
# [4470]	loss:	0.07440	Took	2.70 s
# [4480]	loss:	0.11007	Took	2.74 s
# [4490]	loss:	0.06902	Took	2.73 s
# [4500]	loss:	0.06499	Took	2.71 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 298/400 = 74.50%
# [4510]	loss:	0.06934	Took	2.76 s
# [4520]	loss:	0.06981	Took	2.77 s
# [4530]	loss:	0.07814	Took	2.75 s
# [4540]	loss:	0.06877	Took	2.75 s
# [4550]	loss:	0.06600	Took	2.74 s
# [4560]	loss:	0.06301	Took	2.77 s
# [4570]	loss:	0.06554	Took	2.77 s
# [4580]	loss:	0.04324	Took	2.74 s
# [4590]	loss:	0.07255	Took	2.81 s
# [4600]	loss:	0.07294	Took	2.80 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 306/400 = 76.50%
# [4610]	loss:	0.05843	Took	2.70 s
# [4620]	loss:	0.05466	Took	2.62 s
# [4630]	loss:	0.05932	Took	2.80 s
# [4640]	loss:	0.06227	Took	2.73 s
# [4650]	loss:	0.06557	Took	2.74 s
# [4660]	loss:	0.07660	Took	2.73 s
# [4670]	loss:	0.05534	Took	2.74 s
# [4680]	loss:	0.05904	Took	2.68 s
# [4690]	loss:	0.04814	Took	2.75 s
# [4700]	loss:	0.06501	Took	2.68 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 290/400 = 72.50%
# [4710]	loss:	0.06293	Took	2.67 s
# [4720]	loss:	0.06030	Took	2.71 s
# [4730]	loss:	0.05732	Took	2.76 s
# [4740]	loss:	0.07023	Took	2.74 s
# [4750]	loss:	0.05745	Took	2.73 s
# [4760]	loss:	0.07868	Took	2.76 s
# [4770]	loss:	0.04988	Took	2.41 s
# [4780]	loss:	0.07629	Took	2.72 s
# [4790]	loss:	0.06249	Took	2.75 s
# [4800]	loss:	0.08140	Took	2.72 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 311/400 = 77.75%
# [4810]	loss:	0.07390	Took	2.75 s
# [4820]	loss:	0.07302	Took	2.75 s
# [4830]	loss:	0.05019	Took	2.72 s
# [4840]	loss:	0.06322	Took	2.81 s
# [4850]	loss:	0.05939	Took	2.64 s
# [4860]	loss:	0.06754	Took	2.73 s
# [4870]	loss:	0.05855	Took	2.76 s
# [4880]	loss:	0.05280	Took	2.73 s
# [4890]	loss:	0.06384	Took	2.63 s
# [4900]	loss:	0.07932	Took	2.80 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 283/400 = 70.75%
# [4910]	loss:	0.07477	Took	2.74 s
# [4920]	loss:	0.05633	Took	2.65 s
# [4930]	loss:	0.06188	Took	2.75 s
# [4940]	loss:	0.07753	Took	2.75 s
# [4950]	loss:	0.04914	Took	2.76 s
# [4960]	loss:	0.05668	Took	2.70 s
# [4970]	loss:	0.05887	Took	2.75 s
# [4980]	loss:	0.09179	Took	2.85 s
# [4990]	loss:	0.05667	Took	2.75 s
# [5000]	loss:	0.06371	Took	2.72 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 306/400 = 76.50%
# [5010]	loss:	0.07248	Took	2.88 s
# [5020]	loss:	0.05525	Took	2.65 s
# [5030]	loss:	0.05690	Took	2.77 s
# [5040]	loss:	0.05916	Took	2.72 s
# [5050]	loss:	0.05377	Took	2.75 s
# [5060]	loss:	0.08268	Took	2.71 s
# [5070]	loss:	0.06260	Took	2.74 s
# [5080]	loss:	0.04376	Took	2.73 s
# [5090]	loss:	0.05090	Took	2.70 s
# [5100]	loss:	0.06039	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 297/400 = 74.25%
# [5110]	loss:	0.06729	Took	2.76 s
# [5120]	loss:	0.06847	Took	2.73 s
# [5130]	loss:	0.05126	Took	2.76 s
# [5140]	loss:	0.07376	Took	2.72 s
# [5150]	loss:	0.06201	Took	2.68 s
# [5160]	loss:	0.06327	Took	2.72 s
# [5170]	loss:	0.07034	Took	2.73 s
# [5180]	loss:	0.07439	Took	2.74 s
# [5190]	loss:	0.06750	Took	2.84 s
# [5200]	loss:	0.05485	Took	2.49 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 292/400 = 73.00%
# [5210]	loss:	0.05218	Took	2.74 s
# [5220]	loss:	0.06223	Took	2.76 s
# [5230]	loss:	0.06107	Took	2.55 s
# [5240]	loss:	0.04737	Took	2.67 s
# [5250]	loss:	0.06247	Took	2.76 s
# [5260]	loss:	0.07270	Took	2.73 s
# [5270]	loss:	0.07056	Took	2.64 s
# [5280]	loss:	0.06925	Took	2.78 s
# [5290]	loss:	0.06019	Took	2.81 s
# [5300]	loss:	0.06863	Took	2.72 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 307/400 = 76.75%
# [5310]	loss:	0.06798	Took	2.75 s
# [5320]	loss:	0.06345	Took	2.79 s
# [5330]	loss:	0.06786	Took	2.74 s
# [5340]	loss:	0.07605	Took	2.72 s
# [5350]	loss:	0.05077	Took	2.75 s
# [5360]	loss:	0.05978	Took	2.71 s
# [5370]	loss:	0.06445	Took	2.84 s
# [5380]	loss:	0.05438	Took	2.71 s
# [5390]	loss:	0.06637	Took	2.72 s
# [5400]	loss:	0.07574	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 287/400 = 71.75%
# [5410]	loss:	0.06720	Took	2.73 s
# [5420]	loss:	0.05657	Took	2.70 s
# [5430]	loss:	0.06210	Took	2.71 s
# [5440]	loss:	0.06732	Took	2.73 s
# [5450]	loss:	0.06323	Took	2.77 s
# [5460]	loss:	0.05633	Took	2.73 s
# [5470]	loss:	0.05819	Took	2.75 s
# [5480]	loss:	0.07441	Took	2.71 s
# [5490]	loss:	0.06583	Took	2.75 s
# [5500]	loss:	0.08028	Took	2.63 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 295/400 = 73.75%
# [5510]	loss:	0.04906	Took	2.72 s
# [5520]	loss:	0.05475	Took	2.77 s
# [5530]	loss:	0.04071	Took	2.75 s
# [5540]	loss:	0.07033	Took	2.80 s
# [5550]	loss:	0.05631	Took	2.73 s
# [5560]	loss:	0.05476	Took	2.72 s
# [5570]	loss:	0.07703	Took	2.77 s
# [5580]	loss:	0.06434	Took	2.68 s
# [5590]	loss:	0.05629	Took	2.76 s
# [5600]	loss:	0.06788	Took	2.73 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 310/400 = 77.50%
# [5610]	loss:	0.08402	Took	2.71 s
# [5620]	loss:	0.07954	Took	2.74 s
# [5630]	loss:	0.07579	Took	2.73 s
# [5640]	loss:	0.07647	Took	2.73 s
# [5650]	loss:	0.05068	Took	2.70 s
# [5660]	loss:	0.06541	Took	2.75 s
# [5670]	loss:	0.07213	Took	2.74 s
# [5680]	loss:	0.04547	Took	2.67 s
# [5690]	loss:	0.06472	Took	2.73 s
# [5700]	loss:	0.06531	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 309/400 = 77.25%
# [5710]	loss:	0.04485	Took	2.71 s
# [5720]	loss:	0.06934	Took	2.76 s
# [5730]	loss:	0.05239	Took	2.77 s
# [5740]	loss:	0.06629	Took	2.72 s
# [5750]	loss:	0.05403	Took	2.64 s
# [5760]	loss:	0.04894	Took	2.85 s
# [5770]	loss:	0.05189	Took	2.73 s
# [5780]	loss:	0.05257	Took	2.72 s
# [5790]	loss:	0.05872	Took	2.75 s
# [5800]	loss:	0.06764	Took	2.72 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 300/400 = 75.00%
# [5810]	loss:	0.05257	Took	2.73 s
# [5820]	loss:	0.03844	Took	2.88 s
# [5830]	loss:	0.04991	Took	2.73 s
# [5840]	loss:	0.04110	Took	2.94 s
# [5850]	loss:	0.06321	Took	2.69 s
# [5860]	loss:	0.05049	Took	2.75 s
# [5870]	loss:	0.04182	Took	2.73 s
# [5880]	loss:	0.06149	Took	2.73 s
# [5890]	loss:	0.04800	Took	2.75 s
# [5900]	loss:	0.05453	Took	2.73 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 314/400 = 78.50%
# [5910]	loss:	0.06856	Took	2.73 s
# [5920]	loss:	0.04879	Took	2.80 s
# [5930]	loss:	0.06243	Took	2.65 s
# [5940]	loss:	0.06521	Took	2.78 s
# [5950]	loss:	0.04950	Took	2.73 s
# [5960]	loss:	0.05490	Took	2.58 s
# [5970]	loss:	0.04691	Took	2.63 s
# [5980]	loss:	0.06851	Took	2.78 s
# [5990]	loss:	0.06371	Took	2.81 s
# [6000]	loss:	0.04576	Took	2.78 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 303/400 = 75.75%
# [6010]	loss:	0.06013	Took	2.73 s
# [6020]	loss:	0.05570	Took	2.81 s
# [6030]	loss:	0.04958	Took	2.81 s
# [6040]	loss:	0.05613	Took	2.79 s
# [6050]	loss:	0.06349	Took	2.77 s
# [6060]	loss:	0.04917	Took	2.73 s
# [6070]	loss:	0.03786	Took	2.78 s
# [6080]	loss:	0.06217	Took	2.77 s
# [6090]	loss:	0.05471	Took	2.81 s
# [6100]	loss:	0.06255	Took	2.78 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 304/400 = 76.00%
# [6110]	loss:	0.07113	Took	2.74 s
# [6120]	loss:	0.06077	Took	2.78 s
# [6130]	loss:	0.05160	Took	2.75 s
# [6140]	loss:	0.06680	Took	2.79 s
# [6150]	loss:	0.04303	Took	2.79 s
# [6160]	loss:	0.06273	Took	2.75 s
# [6170]	loss:	0.06761	Took	2.77 s
# [6180]	loss:	0.04708	Took	2.76 s
# [6190]	loss:	0.04194	Took	2.72 s
# [6200]	loss:	0.05408	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 310/400 = 77.50%
# [6210]	loss:	0.05725	Took	2.76 s
# [6220]	loss:	0.03763	Took	2.72 s
# [6230]	loss:	0.05710	Took	2.60 s
# [6240]	loss:	0.05269	Took	2.77 s
# [6250]	loss:	0.05682	Took	2.76 s
# [6260]	loss:	0.05509	Took	2.77 s
# [6270]	loss:	0.05105	Took	2.64 s
# [6280]	loss:	0.05330	Took	2.73 s
# [6290]	loss:	0.04979	Took	2.76 s
# [6300]	loss:	0.06617	Took	2.66 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 314/400 = 78.50%
# [6310]	loss:	0.04325	Took	2.69 s
# [6320]	loss:	0.05040	Took	2.75 s
# [6330]	loss:	0.05076	Took	2.77 s
# [6340]	loss:	0.07346	Took	2.71 s
# [6350]	loss:	0.05073	Took	2.82 s
# [6360]	loss:	0.03838	Took	2.51 s
# [6370]	loss:	0.04778	Took	2.78 s
# [6380]	loss:	0.05627	Took	2.79 s
# [6390]	loss:	0.03999	Took	2.76 s
# [6400]	loss:	0.04531	Took	2.83 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 309/400 = 77.25%
# [6410]	loss:	0.04976	Took	2.78 s
# [6420]	loss:	0.06102	Took	2.76 s
# [6430]	loss:	0.07446	Took	2.90 s
# [6440]	loss:	0.08154	Took	2.66 s
# [6450]	loss:	0.05109	Took	2.80 s
# [6460]	loss:	0.03889	Took	2.77 s
# [6470]	loss:	0.05497	Took	2.77 s
# [6480]	loss:	0.07182	Took	2.70 s
# [6490]	loss:	0.06609	Took	2.74 s
# [6500]	loss:	0.06878	Took	2.79 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 309/400 = 77.25%
# [6510]	loss:	0.06051	Took	2.68 s
# [6520]	loss:	0.04924	Took	2.72 s
# [6530]	loss:	0.04674	Took	2.78 s
# [6540]	loss:	0.04877	Took	2.79 s
# [6550]	loss:	0.05899	Took	2.79 s
# [6560]	loss:	0.05362	Took	2.80 s
# [6570]	loss:	0.05677	Took	2.61 s
# [6580]	loss:	0.03982	Took	2.76 s
# [6590]	loss:	0.06660	Took	2.77 s
# [6600]	loss:	0.06073	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 290/400 = 72.50%
# [6610]	loss:	0.04975	Took	2.79 s
# [6620]	loss:	0.05547	Took	2.78 s
# [6630]	loss:	0.04761	Took	2.79 s
# [6640]	loss:	0.05827	Took	2.80 s
# [6650]	loss:	0.05665	Took	2.85 s
# [6660]	loss:	0.06140	Took	2.74 s
# [6670]	loss:	0.06175	Took	2.75 s
# [6680]	loss:	0.06500	Took	2.75 s
# [6690]	loss:	0.06346	Took	2.81 s
# [6700]	loss:	0.04560	Took	2.92 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 291/400 = 72.75%
# [6710]	loss:	0.05544	Took	2.81 s
# [6720]	loss:	0.04590	Took	2.77 s
# [6730]	loss:	0.03839	Took	2.81 s
# [6740]	loss:	0.03190	Took	2.78 s
# [6750]	loss:	0.05242	Took	2.78 s
# [6760]	loss:	0.04010	Took	2.71 s
# [6770]	loss:	0.04340	Took	2.74 s
# [6780]	loss:	0.05548	Took	2.76 s
# [6790]	loss:	0.07221	Took	2.65 s
# [6800]	loss:	0.05306	Took	2.79 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 304/400 = 76.00%
# [6810]	loss:	0.05078	Took	2.78 s
# [6820]	loss:	0.04080	Took	2.67 s
# [6830]	loss:	0.05503	Took	2.79 s
# [6840]	loss:	0.05073	Took	2.76 s
# [6850]	loss:	0.05139	Took	2.79 s
# [6860]	loss:	0.04849	Took	2.66 s
# [6870]	loss:	0.04494	Took	2.62 s
# [6880]	loss:	0.04336	Took	2.76 s
# [6890]	loss:	0.04716	Took	2.73 s
# [6900]	loss:	0.06221	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 310/400 = 77.50%
# [6910]	loss:	0.05516	Took	2.64 s
# [6920]	loss:	0.04720	Took	2.78 s
# [6930]	loss:	0.05984	Took	2.78 s
# [6940]	loss:	0.04746	Took	2.58 s
# [6950]	loss:	0.04851	Took	2.71 s
# [6960]	loss:	0.04790	Took	2.76 s
# [6970]	loss:	0.04701	Took	2.78 s
# [6980]	loss:	0.03657	Took	2.77 s
# [6990]	loss:	0.03359	Took	2.65 s
# [7000]	loss:	0.05770	Took	2.87 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 317/400 = 79.25%
# [7010]	loss:	0.05279	Took	2.77 s
# [7020]	loss:	0.06858	Took	2.82 s
# [7030]	loss:	0.05195	Took	2.74 s
# [7040]	loss:	0.05890	Took	2.79 s
# [7050]	loss:	0.05747	Took	2.78 s
# [7060]	loss:	0.04895	Took	2.73 s
# [7070]	loss:	0.04994	Took	2.62 s
# [7080]	loss:	0.06059	Took	2.78 s
# [7090]	loss:	0.04928	Took	2.75 s
# [7100]	loss:	0.06682	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 297/400 = 74.25%
# [7110]	loss:	0.06258	Took	2.59 s
# [7120]	loss:	0.04855	Took	2.77 s
# [7130]	loss:	0.04533	Took	2.74 s
# [7140]	loss:	0.07527	Took	2.71 s
# [7150]	loss:	0.05306	Took	2.76 s
# [7160]	loss:	0.04498	Took	2.67 s
# [7170]	loss:	0.04893	Took	2.72 s
# [7180]	loss:	0.06404	Took	2.78 s
# [7190]	loss:	0.05470	Took	2.79 s
# [7200]	loss:	0.04656	Took	2.79 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 310/400 = 77.50%
# [7210]	loss:	0.05443	Took	2.73 s
# [7220]	loss:	0.05780	Took	2.79 s
# [7230]	loss:	0.05594	Took	2.79 s
# [7240]	loss:	0.04933	Took	2.90 s
# [7250]	loss:	0.06568	Took	2.89 s
# [7260]	loss:	0.05148	Took	2.77 s
# [7270]	loss:	0.05043	Took	2.79 s
# [7280]	loss:	0.05072	Took	2.78 s
# [7290]	loss:	0.05332	Took	2.59 s
# [7300]	loss:	0.04329	Took	2.59 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 306/400 = 76.50%
# [7310]	loss:	0.03713	Took	2.77 s
# [7320]	loss:	0.05881	Took	2.86 s
# [7330]	loss:	0.03886	Took	2.70 s
# [7340]	loss:	0.03814	Took	2.78 s
# [7350]	loss:	0.06605	Took	2.78 s
# [7360]	loss:	0.03965	Took	2.75 s
# [7370]	loss:	0.03659	Took	2.73 s
# [7380]	loss:	0.04359	Took	2.55 s
# [7390]	loss:	0.03933	Took	2.76 s
# [7400]	loss:	0.05199	Took	2.59 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 293/400 = 73.25%
# [7410]	loss:	0.04432	Took	2.73 s
# [7420]	loss:	0.07101	Took	2.77 s
# [7430]	loss:	0.05748	Took	2.77 s
# [7440]	loss:	0.05856	Took	2.78 s
# [7450]	loss:	0.04329	Took	2.78 s
# [7460]	loss:	0.04494	Took	2.71 s
# [7470]	loss:	0.04696	Took	2.71 s
# [7480]	loss:	0.04507	Took	2.78 s
# [7490]	loss:	0.06471	Took	2.81 s
# [7500]	loss:	0.05792	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 303/400 = 75.75%
# [7510]	loss:	0.04770	Took	2.78 s
# [7520]	loss:	0.05791	Took	2.78 s
# [7530]	loss:	0.06810	Took	2.77 s
# [7540]	loss:	0.03721	Took	2.74 s
# [7550]	loss:	0.04267	Took	2.72 s
# [7560]	loss:	0.05628	Took	2.72 s
# [7570]	loss:	0.05150	Took	2.75 s
# [7580]	loss:	0.07881	Took	2.77 s
# [7590]	loss:	0.05077	Took	2.78 s
# [7600]	loss:	0.06273	Took	2.89 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 309/400 = 77.25%
# [7610]	loss:	0.04687	Took	2.78 s
# [7620]	loss:	0.04794	Took	2.77 s
# [7630]	loss:	0.04908	Took	2.94 s
# [7640]	loss:	0.03973	Took	2.78 s
# [7650]	loss:	0.06476	Took	2.74 s
# [7660]	loss:	0.06602	Took	2.74 s
# [7670]	loss:	0.06453	Took	2.77 s
# [7680]	loss:	0.05395	Took	2.73 s
# [7690]	loss:	0.04276	Took	2.76 s
# [7700]	loss:	0.03011	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 297/400 = 74.25%
# [7710]	loss:	0.03435	Took	2.74 s
# [7720]	loss:	0.04764	Took	2.74 s
# [7730]	loss:	0.05268	Took	2.78 s
# [7740]	loss:	0.04317	Took	2.79 s
# [7750]	loss:	0.05840	Took	2.83 s
# [7760]	loss:	0.05953	Took	2.81 s
# [7770]	loss:	0.04847	Took	2.80 s
# [7780]	loss:	0.06429	Took	2.76 s
# [7790]	loss:	0.04925	Took	2.75 s
# [7800]	loss:	0.05354	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 295/400 = 73.75%
# [7810]	loss:	0.04327	Took	2.74 s
# [7820]	loss:	0.06484	Took	2.78 s
# [7830]	loss:	0.03767	Took	2.81 s
# [7840]	loss:	0.03544	Took	2.74 s
# [7850]	loss:	0.05244	Took	2.75 s
# [7860]	loss:	0.04518	Took	2.74 s
# [7870]	loss:	0.04588	Took	2.75 s
# [7880]	loss:	0.03862	Took	2.81 s
# [7890]	loss:	0.04012	Took	2.78 s
# [7900]	loss:	0.03445	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 293/400 = 73.25%
# [7910]	loss:	0.04723	Took	2.76 s
# [7920]	loss:	0.04618	Took	2.60 s
# [7930]	loss:	0.03607	Took	2.75 s
# [7940]	loss:	0.05567	Took	2.76 s
# [7950]	loss:	0.04043	Took	2.78 s
# [7960]	loss:	0.05094	Took	2.78 s
# [7970]	loss:	0.06643	Took	2.57 s
# [7980]	loss:	0.05091	Took	2.75 s
# [7990]	loss:	0.05569	Took	2.73 s
# [8000]	loss:	0.05063	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 321/400 = 80.25%
# [8010]	loss:	0.05554	Took	2.70 s
# [8020]	loss:	0.03969	Took	2.78 s
# [8030]	loss:	0.04559	Took	2.77 s
# [8040]	loss:	0.02379	Took	2.76 s
# [8050]	loss:	0.05534	Took	2.79 s
# [8060]	loss:	0.05326	Took	2.72 s
# [8070]	loss:	0.03852	Took	2.78 s
# [8080]	loss:	0.04157	Took	2.75 s
# [8090]	loss:	0.06785	Took	2.76 s
# [8100]	loss:	0.06186	Took	2.88 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 314/400 = 78.50%
# [8110]	loss:	0.05421	Took	2.65 s
# [8120]	loss:	0.06922	Took	2.77 s
# [8130]	loss:	0.05411	Took	3.00 s
# [8140]	loss:	0.04227	Took	2.68 s
# [8150]	loss:	0.04319	Took	2.76 s
# [8160]	loss:	0.04714	Took	2.67 s
# [8170]	loss:	0.05339	Took	2.74 s
# [8180]	loss:	0.03386	Took	2.72 s
# [8190]	loss:	0.05204	Took	2.74 s
# [8200]	loss:	0.04127	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 307/400 = 76.75%
# [8210]	loss:	0.05261	Took	2.78 s
# [8220]	loss:	0.04094	Took	2.84 s
# [8230]	loss:	0.03853	Took	2.78 s
# [8240]	loss:	0.06360	Took	2.76 s
# [8250]	loss:	0.05081	Took	2.74 s
# [8260]	loss:	0.04665	Took	2.72 s
# [8270]	loss:	0.03382	Took	2.67 s
# [8280]	loss:	0.03635	Took	2.69 s
# [8290]	loss:	0.04474	Took	2.77 s
# [8300]	loss:	0.04534	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 303/400 = 75.75%
# [8310]	loss:	0.03877	Took	2.76 s
# [8320]	loss:	0.04389	Took	2.77 s
# [8330]	loss:	0.04300	Took	2.75 s
# [8340]	loss:	0.03147	Took	2.77 s
# [8350]	loss:	0.04752	Took	2.68 s
# [8360]	loss:	0.02478	Took	2.79 s
# [8370]	loss:	0.05309	Took	2.77 s
# [8380]	loss:	0.04416	Took	2.76 s
# [8390]	loss:	0.03249	Took	2.75 s
# [8400]	loss:	0.04087	Took	2.88 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 311/400 = 77.75%
# [8410]	loss:	0.05760	Took	2.69 s
# [8420]	loss:	0.04768	Took	2.80 s
# [8430]	loss:	0.05346	Took	2.86 s
# [8440]	loss:	0.05163	Took	2.70 s
# [8450]	loss:	0.03669	Took	2.74 s
# [8460]	loss:	0.04146	Took	2.68 s
# [8470]	loss:	0.06180	Took	2.75 s
# [8480]	loss:	0.03259	Took	2.86 s
# [8490]	loss:	0.07329	Took	2.73 s
# [8500]	loss:	0.05185	Took	2.79 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 319/400 = 79.75%
# [8510]	loss:	0.06329	Took	2.79 s
# [8520]	loss:	0.07212	Took	2.84 s
# [8530]	loss:	0.04490	Took	2.76 s
# [8540]	loss:	0.04653	Took	2.74 s
# [8550]	loss:	0.05438	Took	2.76 s
# [8560]	loss:	0.04726	Took	2.77 s
# [8570]	loss:	0.05488	Took	2.78 s
# [8580]	loss:	0.04135	Took	2.78 s
# [8590]	loss:	0.05506	Took	2.76 s
# [8600]	loss:	0.05209	Took	2.78 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 322/400 = 80.50%
# [8610]	loss:	0.05896	Took	2.79 s
# [8620]	loss:	0.03741	Took	2.78 s
# [8630]	loss:	0.04227	Took	2.77 s
# [8640]	loss:	0.04088	Took	2.75 s
# [8650]	loss:	0.04773	Took	2.79 s
# [8660]	loss:	0.04591	Took	2.73 s
# [8670]	loss:	0.04677	Took	2.80 s
# [8680]	loss:	0.02774	Took	2.77 s
# [8690]	loss:	0.04054	Took	2.79 s
# [8700]	loss:	0.03665	Took	2.71 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 305/400 = 76.25%
# [8710]	loss:	0.03692	Took	2.73 s
# [8720]	loss:	0.04080	Took	2.76 s
# [8730]	loss:	0.02863	Took	2.70 s
# [8740]	loss:	0.04791	Took	2.76 s
# [8750]	loss:	0.04250	Took	2.78 s
# [8760]	loss:	0.04916	Took	2.76 s
# [8770]	loss:	0.06230	Took	2.78 s
# [8780]	loss:	0.05299	Took	2.83 s
# [8790]	loss:	0.05235	Took	2.66 s
# [8800]	loss:	0.04858	Took	2.79 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 312/400 = 78.00%
# [8810]	loss:	0.03332	Took	2.81 s
# [8820]	loss:	0.05639	Took	2.75 s
# [8830]	loss:	0.07047	Took	2.78 s
# [8840]	loss:	0.05651	Took	2.76 s
# [8850]	loss:	0.04510	Took	2.74 s
# [8860]	loss:	0.02704	Took	2.83 s
# [8870]	loss:	0.05841	Took	2.82 s
# [8880]	loss:	0.04478	Took	2.78 s
# [8890]	loss:	0.04259	Took	2.70 s
# [8900]	loss:	0.04703	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 317/400 = 79.25%
# [8910]	loss:	0.03423	Took	2.77 s
# [8920]	loss:	0.04074	Took	2.76 s
# [8930]	loss:	0.05645	Took	2.75 s
# [8940]	loss:	0.04016	Took	2.68 s
# [8950]	loss:	0.04318	Took	2.89 s
# [8960]	loss:	0.04550	Took	2.74 s
# [8970]	loss:	0.02491	Took	2.79 s
# [8980]	loss:	0.04262	Took	2.77 s
# [8990]	loss:	0.03953	Took	2.76 s
# [9000]	loss:	0.05430	Took	2.72 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 311/400 = 77.75%
# [9010]	loss:	0.05045	Took	2.75 s
# [9020]	loss:	0.04575	Took	2.74 s
# [9030]	loss:	0.04243	Took	2.92 s
# [9040]	loss:	0.04802	Took	2.71 s
# [9050]	loss:	0.04633	Took	2.78 s
# [9060]	loss:	0.03970	Took	2.77 s
# [9070]	loss:	0.04635	Took	2.78 s
# [9080]	loss:	0.04204	Took	2.68 s
# [9090]	loss:	0.05543	Took	2.64 s
# [9100]	loss:	0.05064	Took	2.79 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 317/400 = 79.25%
# [9110]	loss:	0.04712	Took	2.67 s
# [9120]	loss:	0.03836	Took	2.79 s
# [9130]	loss:	0.03139	Took	2.77 s
# [9140]	loss:	0.03607	Took	2.77 s
# [9150]	loss:	0.04059	Took	2.75 s
# [9160]	loss:	0.03656	Took	2.76 s
# [9170]	loss:	0.05063	Took	2.60 s
# [9180]	loss:	0.03487	Took	2.77 s
# [9190]	loss:	0.03945	Took	2.78 s
# [9200]	loss:	0.03441	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 314/400 = 78.50%
# [9210]	loss:	0.04682	Took	2.79 s
# [9220]	loss:	0.03647	Took	2.80 s
# [9230]	loss:	0.05673	Took	2.76 s
# [9240]	loss:	0.05016	Took	2.80 s
# [9250]	loss:	0.03693	Took	2.75 s
# [9260]	loss:	0.04697	Took	2.76 s
# [9270]	loss:	0.04223	Took	2.76 s
# [9280]	loss:	0.03721	Took	2.77 s
# [9290]	loss:	0.04198	Took	2.88 s
# [9300]	loss:	0.03348	Took	2.72 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 301/400 = 75.25%
# [9310]	loss:	0.04175	Took	2.77 s
# [9320]	loss:	0.03312	Took	2.84 s
# [9330]	loss:	0.04271	Took	2.82 s
# [9340]	loss:	0.05670	Took	2.76 s
# [9350]	loss:	0.03078	Took	2.73 s
# [9360]	loss:	0.05149	Took	2.74 s
# [9370]	loss:	0.03713	Took	2.77 s
# [9380]	loss:	0.02777	Took	2.80 s
# [9390]	loss:	0.04523	Took	2.76 s
# [9400]	loss:	0.04985	Took	2.78 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 308/400 = 77.00%
# [9410]	loss:	0.03747	Took	2.61 s
# [9420]	loss:	0.04105	Took	2.73 s
# [9430]	loss:	0.03512	Took	2.75 s
# [9440]	loss:	0.04838	Took	2.77 s
# [9450]	loss:	0.04628	Took	2.77 s
# [9460]	loss:	0.03906	Took	2.77 s
# [9470]	loss:	0.04213	Took	2.68 s
# [9480]	loss:	0.04073	Took	2.77 s
# [9490]	loss:	0.03019	Took	2.76 s
# [9500]	loss:	0.03403	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 304/400 = 76.00%
# [9510]	loss:	0.04436	Took	2.77 s
# [9520]	loss:	0.03950	Took	2.75 s
# [9530]	loss:	0.02777	Took	2.75 s
# [9540]	loss:	0.04244	Took	2.80 s
# [9550]	loss:	0.04723	Took	2.75 s
# [9560]	loss:	0.02707	Took	2.78 s
# [9570]	loss:	0.05762	Took	2.75 s
# [9580]	loss:	0.03950	Took	2.78 s
# [9590]	loss:	0.04504	Took	2.76 s
# [9600]	loss:	0.03325	Took	2.69 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 301/400 = 75.25%
# [9610]	loss:	0.04596	Took	2.76 s
# [9620]	loss:	0.05375	Took	2.77 s
# [9630]	loss:	0.03567	Took	2.72 s
# [9640]	loss:	0.05118	Took	2.77 s
# [9650]	loss:	0.02552	Took	2.79 s
# [9660]	loss:	0.05102	Took	2.79 s
# [9670]	loss:	0.03792	Took	2.83 s
# [9680]	loss:	0.03275	Took	2.69 s
# [9690]	loss:	0.04844	Took	2.76 s
# [9700]	loss:	0.04678	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 327/400 = 81.75%
# [9710]	loss:	0.05762	Took	2.71 s
# [9720]	loss:	0.05683	Took	2.79 s
# [9730]	loss:	0.04621	Took	2.77 s
# [9740]	loss:	0.04162	Took	2.78 s
# [9750]	loss:	0.05222	Took	2.76 s
# [9760]	loss:	0.04693	Took	2.79 s
# [9770]	loss:	0.05615	Took	2.56 s
# [9780]	loss:	0.06050	Took	2.81 s
# [9790]	loss:	0.03375	Took	2.74 s
# [9800]	loss:	0.03595	Took	2.78 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 293/400 = 73.25%
# [9810]	loss:	0.04328	Took	2.65 s
# [9820]	loss:	0.04035	Took	2.77 s
# [9830]	loss:	0.05201	Took	2.77 s
# [9840]	loss:	0.05660	Took	2.67 s
# [9850]	loss:	0.03752	Took	2.58 s
# [9860]	loss:	0.03796	Took	2.77 s
# [9870]	loss:	0.03901	Took	2.73 s
# [9880]	loss:	0.04599	Took	2.76 s
# [9890]	loss:	0.03655	Took	2.78 s
# [9900]	loss:	0.04112	Took	2.86 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 319/400 = 79.75%
# [9910]	loss:	0.06212	Took	2.78 s
# [9920]	loss:	0.04791	Took	2.84 s
# [9930]	loss:	0.06651	Took	2.86 s
# [9940]	loss:	0.04449	Took	2.78 s
# [9950]	loss:	0.03277	Took	2.79 s
# [9960]	loss:	0.03966	Took	2.77 s
# [9970]	loss:	0.05293	Took	2.64 s
# [9980]	loss:	0.04511	Took	2.85 s
# [9990]	loss:	0.03189	Took	2.78 s
# [10000]	loss:	0.03703	Took	2.79 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 310/400 = 77.50%
# [10010]	loss:	0.03484	Took	2.84 s
# [10020]	loss:	0.05266	Took	2.74 s
# [10030]	loss:	0.03308	Took	2.73 s
# [10040]	loss:	0.06389	Took	2.75 s
# [10050]	loss:	0.03268	Took	2.78 s
# [10060]	loss:	0.05873	Took	2.77 s
# [10070]	loss:	0.03623	Took	2.78 s
# [10080]	loss:	0.05568	Took	2.76 s
# [10090]	loss:	0.04884	Took	2.77 s
# [10100]	loss:	0.03814	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 322/400 = 80.50%
# [10110]	loss:	0.03724	Took	2.75 s
# [10120]	loss:	0.05329	Took	2.74 s
# [10130]	loss:	0.04857	Took	2.73 s
# [10140]	loss:	0.03837	Took	2.74 s
# [10150]	loss:	0.04706	Took	2.74 s
# [10160]	loss:	0.03558	Took	2.77 s
# [10170]	loss:	0.03497	Took	2.76 s
# [10180]	loss:	0.03869	Took	2.78 s
# [10190]	loss:	0.03045	Took	2.74 s
# [10200]	loss:	0.04631	Took	2.78 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 298/400 = 74.50%
# [10210]	loss:	0.05304	Took	2.78 s
# [10220]	loss:	0.04650	Took	2.72 s
# [10230]	loss:	0.02706	Took	2.63 s
# [10240]	loss:	0.03213	Took	2.78 s
# [10250]	loss:	0.03689	Took	2.76 s
# [10260]	loss:	0.04236	Took	2.75 s
# [10270]	loss:	0.04076	Took	2.85 s
# [10280]	loss:	0.04614	Took	2.66 s
# [10290]	loss:	0.04430	Took	2.78 s
# [10300]	loss:	0.04897	Took	2.79 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 315/400 = 78.75%
# [10310]	loss:	0.04438	Took	2.81 s
# [10320]	loss:	0.05662	Took	2.77 s
# [10330]	loss:	0.03669	Took	2.71 s
# [10340]	loss:	0.03836	Took	2.75 s
# [10350]	loss:	0.05199	Took	2.81 s
# [10360]	loss:	0.05270	Took	2.84 s
# [10370]	loss:	0.05931	Took	2.76 s
# [10380]	loss:	0.04229	Took	2.76 s
# [10390]	loss:	0.02943	Took	2.71 s
# [10400]	loss:	0.06724	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 316/400 = 79.00%
# [10410]	loss:	0.03368	Took	2.79 s
# [10420]	loss:	0.04381	Took	2.53 s
# [10430]	loss:	0.04053	Took	2.82 s
# [10440]	loss:	0.03344	Took	2.65 s
# [10450]	loss:	0.04024	Took	2.74 s
# [10460]	loss:	0.05184	Took	2.78 s
# [10470]	loss:	0.03043	Took	2.76 s
# [10480]	loss:	0.04707	Took	2.76 s
# [10490]	loss:	0.02871	Took	2.73 s
# [10500]	loss:	0.04650	Took	2.79 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 307/400 = 76.75%
# [10510]	loss:	0.06395	Took	2.78 s
# [10520]	loss:	0.03784	Took	2.70 s
# [10530]	loss:	0.04464	Took	2.78 s
# [10540]	loss:	0.03172	Took	2.77 s
# [10550]	loss:	0.03554	Took	2.76 s
# [10560]	loss:	0.04764	Took	2.77 s
# [10570]	loss:	0.04857	Took	2.79 s
# [10580]	loss:	0.03316	Took	2.79 s
# [10590]	loss:	0.04427	Took	2.76 s
# [10600]	loss:	0.03993	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 333/400 = 83.25%
# [10610]	loss:	0.02058	Took	2.53 s
# [10620]	loss:	0.02782	Took	2.76 s
# [10630]	loss:	0.04129	Took	2.75 s
# [10640]	loss:	0.02618	Took	2.73 s
# [10650]	loss:	0.03348	Took	2.87 s
# [10660]	loss:	0.04691	Took	2.87 s
# [10670]	loss:	0.04170	Took	2.77 s
# [10680]	loss:	0.02790	Took	2.76 s
# [10690]	loss:	0.02869	Took	2.78 s
# [10700]	loss:	0.04877	Took	2.78 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 295/400 = 73.75%
# [10710]	loss:	0.04859	Took	2.74 s
# [10720]	loss:	0.04524	Took	2.79 s
# [10730]	loss:	0.03239	Took	2.82 s
# [10740]	loss:	0.04093	Took	2.73 s
# [10750]	loss:	0.04354	Took	2.75 s
# [10760]	loss:	0.02691	Took	2.79 s
# [10770]	loss:	0.04361	Took	2.77 s
# [10780]	loss:	0.06105	Took	2.71 s
# [10790]	loss:	0.04622	Took	2.90 s
# [10800]	loss:	0.04678	Took	2.71 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 320/400 = 80.00%
# [10810]	loss:	0.02987	Took	2.77 s
# [10820]	loss:	0.03498	Took	2.79 s
# [10830]	loss:	0.03441	Took	2.74 s
# [10840]	loss:	0.02124	Took	2.74 s
# [10850]	loss:	0.04252	Took	2.76 s
# [10860]	loss:	0.03955	Took	2.78 s
# [10870]	loss:	0.03369	Took	2.56 s
# [10880]	loss:	0.03496	Took	2.66 s
# [10890]	loss:	0.02570	Took	2.78 s
# [10900]	loss:	0.02947	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 314/400 = 78.50%
# [10910]	loss:	0.04010	Took	2.73 s
# [10920]	loss:	0.02987	Took	2.75 s
# [10930]	loss:	0.04220	Took	2.76 s
# [10940]	loss:	0.05464	Took	2.78 s
# [10950]	loss:	0.03486	Took	2.69 s
# [10960]	loss:	0.03961	Took	2.71 s
# [10970]	loss:	0.04720	Took	2.76 s
# [10980]	loss:	0.03486	Took	2.74 s
# [10990]	loss:	0.04236	Took	2.76 s
# [11000]	loss:	0.04426	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 323/400 = 80.75%
# [11010]	loss:	0.04414	Took	2.77 s
# [11020]	loss:	0.03061	Took	2.77 s
# [11030]	loss:	0.04197	Took	2.70 s
# [11040]	loss:	0.04969	Took	2.65 s
# [11050]	loss:	0.02326	Took	2.75 s
# [11060]	loss:	0.03645	Took	2.76 s
# [11070]	loss:	0.03212	Took	2.77 s
# [11080]	loss:	0.03541	Took	2.67 s
# [11090]	loss:	0.05331	Took	2.76 s
# [11100]	loss:	0.03546	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 327/400 = 81.75%
# [11110]	loss:	0.07296	Took	2.78 s
# [11120]	loss:	0.03998	Took	2.80 s
# [11130]	loss:	0.03834	Took	2.77 s
# [11140]	loss:	0.06275	Took	2.75 s
# [11150]	loss:	0.03531	Took	2.75 s
# [11160]	loss:	0.02090	Took	2.76 s
# [11170]	loss:	0.04604	Took	2.76 s
# [11180]	loss:	0.04103	Took	2.75 s
# [11190]	loss:	0.02808	Took	2.77 s
# [11200]	loss:	0.03502	Took	2.78 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 308/400 = 77.00%
# [11210]	loss:	0.04073	Took	2.75 s
# [11220]	loss:	0.02625	Took	2.75 s
# [11230]	loss:	0.03875	Took	2.78 s
# [11240]	loss:	0.02356	Took	2.76 s
# [11250]	loss:	0.02995	Took	2.81 s
# [11260]	loss:	0.02664	Took	2.76 s
# [11270]	loss:	0.03865	Took	2.74 s
# [11280]	loss:	0.04711	Took	2.74 s
# [11290]	loss:	0.03512	Took	2.72 s
# [11300]	loss:	0.03766	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 311/400 = 77.75%
# [11310]	loss:	0.02623	Took	2.75 s
# [11320]	loss:	0.04019	Took	2.75 s
# [11330]	loss:	0.03524	Took	2.84 s
# [11340]	loss:	0.05848	Took	2.65 s
# [11350]	loss:	0.02745	Took	2.78 s
# [11360]	loss:	0.04846	Took	2.79 s
# [11370]	loss:	0.04632	Took	2.74 s
# [11380]	loss:	0.02558	Took	2.77 s
# [11390]	loss:	0.03618	Took	2.77 s
# [11400]	loss:	0.03915	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 315/400 = 78.75%
# [11410]	loss:	0.03464	Took	2.82 s
# [11420]	loss:	0.04557	Took	2.78 s
# ...
# [13350]	loss:	0.02994	Took	2.72 s
# [13360]	loss:	0.02773	Took	2.80 s
# [13370]	loss:	0.05542	Took	2.77 s
# [13380]	loss:	0.02366	Took	2.79 s
# [13390]	loss:	0.02604	Took	2.73 s
# [13400]	loss:	0.03491	Took	2.73 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 332/400 = 83.00%
# [13410]	loss:	0.04776	Took	2.71 s
# [13420]	loss:	0.04438	Took	2.74 s
# [13430]	loss:	0.04869	Took	2.77 s
# [13440]	loss:	0.03300	Took	2.77 s
# [13450]	loss:	0.04940	Took	2.77 s
# [13460]	loss:	0.03157	Took	2.76 s
# [13470]	loss:	0.02495	Took	2.77 s
# [13480]	loss:	0.04305	Took	2.70 s
# [13490]	loss:	0.03977	Took	2.70 s
# [13500]	loss:	0.03202	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 290/400 = 72.50%
# [13510]	loss:	0.02806	Took	2.80 s
# [13520]	loss:	0.02994	Took	2.71 s
# [13530]	loss:	0.03298	Took	2.75 s
# [13540]	loss:	0.04050	Took	2.76 s
# [13550]	loss:	0.04448	Took	2.75 s
# [13560]	loss:	0.03725	Took	2.72 s
# [13570]	loss:	0.03740	Took	2.68 s
# [13580]	loss:	0.03105	Took	2.78 s
# [13590]	loss:	0.02802	Took	2.76 s
# [13600]	loss:	0.02640	Took	2.73 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 320/400 = 80.00%
# [13610]	loss:	0.04046	Took	2.73 s
# [13620]	loss:	0.03711	Took	2.74 s
# [13630]	loss:	0.03156	Took	2.77 s
# [13640]	loss:	0.02471	Took	2.84 s
# [13650]	loss:	0.04202	Took	2.83 s
# [13660]	loss:	0.03900	Took	2.78 s
# [13670]	loss:	0.02434	Took	2.74 s
# [13680]	loss:	0.04964	Took	2.74 s
# [13690]	loss:	0.04629	Took	2.75 s
# [13700]	loss:	0.03422	Took	2.82 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 295/400 = 73.75%
# [13710]	loss:	0.03209	Took	2.76 s
# [13720]	loss:	0.02800	Took	2.75 s
# [13730]	loss:	0.01829	Took	2.79 s
# [13740]	loss:	0.03333	Took	2.80 s
# [13750]	loss:	0.03523	Took	2.62 s
# [13760]	loss:	0.02857	Took	2.76 s
# [13770]	loss:	0.02602	Took	2.77 s
# [13780]	loss:	0.03450	Took	2.77 s
# [13790]	loss:	0.02921	Took	2.83 s
# [13800]	loss:	0.02752	Took	2.72 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 310/400 = 77.50%
# [13810]	loss:	0.02796	Took	2.76 s
# [13820]	loss:	0.03151	Took	2.79 s
# [13830]	loss:	0.02077	Took	2.80 s
# [13840]	loss:	0.02165	Took	2.76 s
# [13850]	loss:	0.02077	Took	2.75 s
# [13860]	loss:	0.02043	Took	2.75 s
# [13870]	loss:	0.02227	Took	2.76 s
# [13880]	loss:	0.01311	Took	2.78 s
# [13890]	loss:	0.03935	Took	2.80 s
# [13900]	loss:	0.03162	Took	2.78 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 304/400 = 76.00%
# [13910]	loss:	0.04288	Took	2.71 s
# [13920]	loss:	0.03036	Took	2.63 s
# [13930]	loss:	0.04727	Took	2.75 s
# [13940]	loss:	0.02797	Took	2.78 s
# [13950]	loss:	0.03559	Took	2.74 s
# [13960]	loss:	0.05427	Took	2.68 s
# [13970]	loss:	0.02928	Took	2.82 s
# [13980]	loss:	0.04120	Took	2.75 s
# [13990]	loss:	0.02811	Took	2.77 s
# [14000]	loss:	0.03405	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 312/400 = 78.00%
# [14010]	loss:	0.02951	Took	2.77 s
# [14020]	loss:	0.02775	Took	2.73 s
# [14030]	loss:	0.03516	Took	2.73 s
# [14040]	loss:	0.03593	Took	2.89 s
# [14050]	loss:	0.02654	Took	2.66 s
# [14060]	loss:	0.04130	Took	2.77 s
# [14070]	loss:	0.02512	Took	2.75 s
# [14080]	loss:	0.02839	Took	2.74 s
# [14090]	loss:	0.03476	Took	2.87 s
# [14100]	loss:	0.03901	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 309/400 = 77.25%
# [14110]	loss:	0.03298	Took	2.78 s
# [14120]	loss:	0.03340	Took	2.80 s
# [14130]	loss:	0.04483	Took	2.84 s
# [14140]	loss:	0.02528	Took	2.78 s
# [14150]	loss:	0.03643	Took	2.64 s
# [14160]	loss:	0.02593	Took	2.73 s
# [14170]	loss:	0.03364	Took	2.78 s
# [14180]	loss:	0.02990	Took	2.60 s
# [14190]	loss:	0.02425	Took	2.73 s
# [14200]	loss:	0.02958	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 312/400 = 78.00%
# [14210]	loss:	0.03372	Took	2.66 s
# [14220]	loss:	0.03178	Took	2.74 s
# [14230]	loss:	0.02266	Took	2.74 s
# [14240]	loss:	0.04161	Took	2.73 s
# [14250]	loss:	0.02395	Took	2.75 s
# [14260]	loss:	0.02780	Took	2.92 s
# [14270]	loss:	0.03313	Took	2.75 s
# [14280]	loss:	0.03365	Took	2.66 s
# [14290]	loss:	0.02172	Took	2.76 s
# [14300]	loss:	0.03891	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 310/400 = 77.50%
# [14310]	loss:	0.03544	Took	2.73 s
# [14320]	loss:	0.03955	Took	2.78 s
# [14330]	loss:	0.02637	Took	2.77 s
# [14340]	loss:	0.03685	Took	2.74 s
# [14350]	loss:	0.02182	Took	2.90 s
# [14360]	loss:	0.02850	Took	2.81 s
# [14370]	loss:	0.02308	Took	2.74 s
# [14380]	loss:	0.03293	Took	2.73 s
# [14390]	loss:	0.03846	Took	2.76 s
# [14400]	loss:	0.04549	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 311/400 = 77.75%
# [14410]	loss:	0.04925	Took	2.78 s
# [14420]	loss:	0.03376	Took	2.66 s
# [14430]	loss:	0.03551	Took	2.72 s
# [14440]	loss:	0.03458	Took	2.69 s
# [14450]	loss:	0.03123	Took	2.77 s
# [14460]	loss:	0.02737	Took	2.77 s
# [14470]	loss:	0.03576	Took	2.75 s
# [14480]	loss:	0.03143	Took	2.68 s
# [14490]	loss:	0.02244	Took	2.52 s
# [14500]	loss:	0.04774	Took	2.78 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 312/400 = 78.00%
# [14510]	loss:	0.02905	Took	2.74 s
# [14520]	loss:	0.03303	Took	2.69 s
# [14530]	loss:	0.03369	Took	2.71 s
# [14540]	loss:	0.03112	Took	2.74 s
# [14550]	loss:	0.04955	Took	2.76 s
# [14560]	loss:	0.03112	Took	2.81 s
# [14570]	loss:	0.02471	Took	2.68 s
# [14580]	loss:	0.03958	Took	2.79 s
# [14590]	loss:	0.02069	Took	2.73 s
# [14600]	loss:	0.03480	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 301/400 = 75.25%
# [14610]	loss:	0.05104	Took	2.74 s
# [14620]	loss:	0.02898	Took	2.72 s
# [14630]	loss:	0.04184	Took	2.74 s
# [14640]	loss:	0.02908	Took	2.74 s
# [14650]	loss:	0.03322	Took	2.78 s
# [14660]	loss:	0.03299	Took	2.77 s
# [14670]	loss:	0.03509	Took	2.77 s
# [14680]	loss:	0.03874	Took	2.74 s
# [14690]	loss:	0.02482	Took	2.76 s
# [14700]	loss:	0.02950	Took	2.58 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 315/400 = 78.75%
# [14710]	loss:	0.05536	Took	2.72 s
# [14720]	loss:	0.04047	Took	2.76 s
# [14730]	loss:	0.03020	Took	2.86 s
# [14740]	loss:	0.03158	Took	2.55 s
# [14750]	loss:	0.02528	Took	2.65 s
# [14760]	loss:	0.03012	Took	2.76 s
# [14770]	loss:	0.03534	Took	2.75 s
# [14780]	loss:	0.04494	Took	2.71 s
# [14790]	loss:	0.03811	Took	2.58 s
# [14800]	loss:	0.03230	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 320/400 = 80.00%
# [14810]	loss:	0.02450	Took	2.82 s
# [14820]	loss:	0.02353	Took	2.86 s
# [14830]	loss:	0.02038	Took	2.77 s
# [14840]	loss:	0.03193	Took	2.78 s
# [14850]	loss:	0.02940	Took	2.76 s
# [14860]	loss:	0.04243	Took	2.71 s
# [14870]	loss:	0.03387	Took	2.53 s
# [14880]	loss:	0.04201	Took	2.55 s
# [14890]	loss:	0.03715	Took	2.76 s
# [14900]	loss:	0.04274	Took	2.77 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 310/400 = 77.50%
# [14910]	loss:	0.02147	Took	2.61 s
# [14920]	loss:	0.03367	Took	2.75 s
# [14930]	loss:	0.03391	Took	2.78 s
# [14940]	loss:	0.03071	Took	2.76 s
# [14950]	loss:	0.03425	Took	2.58 s
# [14960]	loss:	0.03132	Took	2.64 s
# [14970]	loss:	0.02451	Took	2.72 s
# [14980]	loss:	0.02487	Took	2.77 s
# [14990]	loss:	0.02749	Took	2.77 s
# [15000]	loss:	0.03086	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 314/400 = 78.50%
# [15010]	loss:	0.02488	Took	2.77 s
# [15020]	loss:	0.03081	Took	2.74 s
# [15030]	loss:	0.03511	Took	2.75 s
# [15040]	loss:	0.04178	Took	2.74 s
# [15050]	loss:	0.04811	Took	2.86 s
# [15060]	loss:	0.02701	Took	2.82 s
# [15070]	loss:	0.04412	Took	2.76 s
# [15080]	loss:	0.02833	Took	2.75 s
# [15090]	loss:	0.03640	Took	2.80 s
# [15100]	loss:	0.03036	Took	2.53 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 317/400 = 79.25%
# [15110]	loss:	0.03173	Took	2.79 s
# [15120]	loss:	0.02943	Took	2.74 s
# [15130]	loss:	0.04449	Took	2.58 s
# [15140]	loss:	0.02727	Took	2.85 s
# [15150]	loss:	0.02148	Took	2.72 s
# [15160]	loss:	0.02433	Took	2.73 s
# [15170]	loss:	0.03633	Took	2.64 s
# [15180]	loss:	0.03732	Took	2.82 s
# [15190]	loss:	0.01524	Took	2.77 s
# [15200]	loss:	0.01877	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 305/400 = 76.25%
# [15210]	loss:	0.04249	Took	2.65 s
# [15220]	loss:	0.02786	Took	2.74 s
# [15230]	loss:	0.03945	Took	2.72 s
# [15240]	loss:	0.04134	Took	2.75 s
# [15250]	loss:	0.02313	Took	2.75 s
# [15260]	loss:	0.02590	Took	2.87 s
# [15270]	loss:	0.04116	Took	2.75 s
# [15280]	loss:	0.02596	Took	2.73 s
# [15290]	loss:	0.03612	Took	2.80 s
# [15300]	loss:	0.02191	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 330/400 = 82.50%
# [15310]	loss:	0.04295	Took	2.78 s
# [15320]	loss:	0.02753	Took	2.75 s
# [15330]	loss:	0.03775	Took	2.73 s
# [15340]	loss:	0.02662	Took	2.70 s
# [15350]	loss:	0.02031	Took	2.74 s
# [15360]	loss:	0.03612	Took	2.77 s
# [15370]	loss:	0.03337	Took	2.77 s
# [15380]	loss:	0.02140	Took	2.78 s
# [15390]	loss:	0.02958	Took	2.75 s
# [15400]	loss:	0.03593	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 315/400 = 78.75%
# [15410]	loss:	0.03225	Took	2.77 s
# [15420]	loss:	0.02543	Took	2.80 s
# [15430]	loss:	0.03060	Took	2.62 s
# [15440]	loss:	0.02831	Took	2.78 s
# [15450]	loss:	0.01796	Took	2.73 s
# [15460]	loss:	0.03581	Took	2.76 s
# [15470]	loss:	0.02743	Took	2.77 s
# [15480]	loss:	0.03183	Took	2.84 s
# [15490]	loss:	0.03122	Took	2.75 s
# [15500]	loss:	0.02776	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 320/400 = 80.00%
# [15510]	loss:	0.03628	Took	2.65 s
# [15520]	loss:	0.03449	Took	2.74 s
# [15530]	loss:	0.04338	Took	2.76 s
# [15540]	loss:	0.03349	Took	2.75 s
# [15550]	loss:	0.03392	Took	2.74 s
# [15560]	loss:	0.03280	Took	2.82 s
# [15570]	loss:	0.02996	Took	2.80 s
# [15580]	loss:	0.02570	Took	2.77 s
# [15590]	loss:	0.03613	Took	2.75 s
# [15600]	loss:	0.03785	Took	2.78 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 307/400 = 76.75%
# [15610]	loss:	0.03219	Took	2.76 s
# [15620]	loss:	0.04338	Took	2.73 s
# [15630]	loss:	0.03096	Took	2.79 s
# [15640]	loss:	0.03709	Took	2.83 s
# [15650]	loss:	0.02761	Took	2.75 s
# [15660]	loss:	0.04137	Took	2.77 s
# [15670]	loss:	0.03799	Took	2.78 s
# [15680]	loss:	0.04177	Took	2.76 s
# [15690]	loss:	0.05051	Took	2.73 s
# [15700]	loss:	0.02218	Took	2.61 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 304/400 = 76.00%
# [15710]	loss:	0.02674	Took	2.80 s
# [15720]	loss:	0.05145	Took	2.75 s
# [15730]	loss:	0.04030	Took	2.71 s
# [15740]	loss:	0.03005	Took	2.83 s
# [15750]	loss:	0.03962	Took	2.77 s
# [15760]	loss:	0.02978	Took	2.62 s
# [15770]	loss:	0.03418	Took	2.75 s
# [15780]	loss:	0.04084	Took	2.76 s
# [15790]	loss:	0.04013	Took	2.71 s
# [15800]	loss:	0.03336	Took	2.54 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 300/400 = 75.00%
# [15810]	loss:	0.05203	Took	2.79 s
# [15820]	loss:	0.03170	Took	2.89 s
# [15830]	loss:	0.03703	Took	2.74 s
# [15840]	loss:	0.03084	Took	2.78 s
# [15850]	loss:	0.04329	Took	2.77 s
# [15860]	loss:	0.03682	Took	2.75 s
# [15870]	loss:	0.03083	Took	2.56 s
# [15880]	loss:	0.03594	Took	2.46 s
# [15890]	loss:	0.03161	Took	2.77 s
# [15900]	loss:	0.02861	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 306/400 = 76.50%
# [15910]	loss:	0.04667	Took	2.68 s
# [15920]	loss:	0.02281	Took	2.77 s
# [15930]	loss:	0.02365	Took	2.77 s
# [15940]	loss:	0.03144	Took	2.75 s
# [15950]	loss:	0.02761	Took	2.79 s
# [15960]	loss:	0.02494	Took	2.75 s
# [15970]	loss:	0.03841	Took	2.78 s
# [15980]	loss:	0.02479	Took	2.75 s
# [15990]	loss:	0.02656	Took	2.76 s
# [16000]	loss:	0.03943	Took	2.73 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 316/400 = 79.00%
# [16010]	loss:	0.03976	Took	2.77 s
# [16020]	loss:	0.04504	Took	2.81 s
# [16030]	loss:	0.03064	Took	2.79 s
# [16040]	loss:	0.02773	Took	2.75 s
# [16050]	loss:	0.02164	Took	2.76 s
# [16060]	loss:	0.02030	Took	2.76 s
# [16070]	loss:	0.02097	Took	2.75 s
# [16080]	loss:	0.02219	Took	2.74 s
# [16090]	loss:	0.02815	Took	2.74 s
# [16100]	loss:	0.05007	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 322/400 = 80.50%
# [16110]	loss:	0.02450	Took	2.75 s
# [16120]	loss:	0.03840	Took	2.84 s
# [16130]	loss:	0.03089	Took	2.72 s
# [16140]	loss:	0.02854	Took	2.76 s
# [16150]	loss:	0.02759	Took	2.74 s
# [16160]	loss:	0.03503	Took	2.74 s
# [16170]	loss:	0.02579	Took	2.77 s
# [16180]	loss:	0.01679	Took	2.71 s
# [16190]	loss:	0.01920	Took	2.75 s
# [16200]	loss:	0.03595	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 311/400 = 77.75%
# [16210]	loss:	0.02965	Took	2.68 s
# [16220]	loss:	0.02526	Took	2.76 s
# [16230]	loss:	0.04216	Took	2.72 s
# [16240]	loss:	0.03542	Took	2.78 s
# [16250]	loss:	0.02974	Took	2.75 s
# [16260]	loss:	0.03206	Took	2.88 s
# [16270]	loss:	0.05842	Took	2.76 s
# [16280]	loss:	0.01978	Took	2.72 s
# [16290]	loss:	0.04082	Took	2.73 s
# [16300]	loss:	0.02374	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 326/400 = 81.50%
# [16310]	loss:	0.03844	Took	2.78 s
# [16320]	loss:	0.03071	Took	2.75 s
# [16330]	loss:	0.03129	Took	2.77 s
# [16340]	loss:	0.03018	Took	2.68 s
# [16350]	loss:	0.02706	Took	2.74 s
# [16360]	loss:	0.03541	Took	2.75 s
# [16370]	loss:	0.04020	Took	2.74 s
# [16380]	loss:	0.03602	Took	2.73 s
# [16390]	loss:	0.03137	Took	2.66 s
# [16400]	loss:	0.03619	Took	2.50 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 315/400 = 78.75%
# [16410]	loss:	0.03058	Took	2.75 s
# [16420]	loss:	0.03229	Took	2.65 s
# [16430]	loss:	0.02754	Took	2.74 s
# [16440]	loss:	0.04444	Took	2.73 s
# [16450]	loss:	0.03984	Took	2.72 s
# [16460]	loss:	0.02462	Took	2.73 s
# [16470]	loss:	0.03261	Took	2.80 s
# [16480]	loss:	0.03213	Took	2.85 s
# [16490]	loss:	0.03749	Took	2.75 s
# [16500]	loss:	0.01526	Took	2.81 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 316/400 = 79.00%
# [16510]	loss:	0.03276	Took	2.92 s
# [16520]	loss:	0.03015	Took	2.76 s
# [16530]	loss:	0.03217	Took	2.74 s
# [16540]	loss:	0.03689	Took	2.60 s
# [16550]	loss:	0.03049	Took	2.76 s
# [16560]	loss:	0.03497	Took	2.50 s
# [16570]	loss:	0.02336	Took	2.79 s
# [16580]	loss:	0.02297	Took	2.74 s
# [16590]	loss:	0.01883	Took	2.76 s
# [16600]	loss:	0.03198	Took	2.75 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 323/400 = 80.75%
# [16610]	loss:	0.02889	Took	2.76 s
# [16620]	loss:	0.02795	Took	2.74 s
# [16630]	loss:	0.04544	Took	2.75 s
# [16640]	loss:	0.01844	Took	2.71 s
# [16650]	loss:	0.01887	Took	2.77 s
# [16660]	loss:	0.02520	Took	2.76 s
# [16670]	loss:	0.02694	Took	2.78 s
# [16680]	loss:	0.03670	Took	2.72 s
# [16690]	loss:	0.02426	Took	2.83 s
# [16700]	loss:	0.02918	Took	2.81 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 308/400 = 77.00%
# [16710]	loss:	0.03291	Took	2.77 s
# [16720]	loss:	0.03100	Took	2.83 s
# [16730]	loss:	0.03506	Took	2.77 s
# [16740]	loss:	0.03610	Took	2.81 s
# [16750]	loss:	0.01923	Took	2.71 s
# [16760]	loss:	0.03802	Took	2.65 s
# [16770]	loss:	0.02733	Took	2.76 s
# [16780]	loss:	0.02656	Took	2.67 s
# [16790]	loss:	0.03281	Took	2.74 s
# [16800]	loss:	0.02835	Took	2.76 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 315/400 = 78.75%
# [16810]	loss:	0.03793	Took	2.80 s
# [16820]	loss:	0.02631	Took	2.83 s
# [16830]	loss:	0.03123	Took	2.72 s
# [16840]	loss:	0.02835	Took	2.73 s
# [16850]	loss:	0.03700	Took	2.77 s
# [16860]	loss:	0.02944	Took	2.72 s
# [16870]	loss:	0.02728	Took	2.59 s
# [16880]	loss:	0.03065	Took	2.75 s
# [16890]	loss:	0.02654	Took	2.75 s
# [16900]	loss:	0.03111	Took	2.74 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 310/400 = 77.50%
# [16910]	loss:	0.02322	Took	2.70 s
# [16920]	loss:	0.02188	Took	2.76 s
# [16930]	loss:	0.02650	Took	2.76 s
# [16940]	loss:	0.03927	Took	2.76 s
# [16950]	loss:	0.01928	Took	2.72 s
# [16960]	loss:	0.02400	Took	2.78 s
# [16970]	loss:	0.02910	Took	2.73 s
# [16980]	loss:	0.03584	Took	2.72 s
# [16990]	loss:	0.02335	Took	2.77 s
# [17000]	loss:	0.02060	Took	2.81 s
# Realizando avaliação One-Shot...
#
# One-Shot Accuracy on 20-way 400-trial: 318/400 = 79.50%
# [17010]	loss:	0.02908	Took	2.81 s
# [17020]	loss:	0.03182	Took	2.76 s
# [17030]	loss:	0.02732	Took	2.76 s
# [17040]	loss:	0.02309	Took	2.61 s
# [17050]	loss:	0.03371	Took	2.76 s
# [17060]	loss:	0.03246	Took	2.76 s

# %% [markdown]
# #Etapa 14: Visualização dos resultados
